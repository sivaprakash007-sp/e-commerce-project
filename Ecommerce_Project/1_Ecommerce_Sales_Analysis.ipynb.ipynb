# %%
plt.savefig("sales_by_region.png")

# %%
plt.savefig("sales_by_category.png")

# %%
df.groupby("Region")["Total_Sales"].sum().plot(kind='bar')
plt.title("Sales by Region")
plt.show()

# %%
import matplotlib.pyplot as plt
df.groupby("Category")["Total_Sales"].sum().plot(kind='bar')
plt.title("Sales by Category")
plt.xlabel("Category")
plt.ylabel("Total Sales")
plt.show()

# %%
print("Total Sales:", df["Total_Sales"].sum())

print("\nSales by Category:")
print(df.groupby("Category")["Total_Sales"].sum())

print("\nSales by Region:")
print(df.groupby("Region")["Total_Sales"].sum())

print("\nTop Customers:")
print(df.groupby("Customer")["Total_Sales"].sum().sort_values(ascending=False))
# Out:
# Total Sales: 62000
#
# Sales by Category:
# Category
# Clothing       13000
# Electronics    49000
# Name: Total_Sales, dtype: int64
#
# Sales by Region:
# Region
# East      9000
# North     4000
# South    25000
# West     24000
# Name: Total_Sales, dtype: int64
#
# Top Customers:
# Customer
# Ravi     28000
# Siva     19000
# Kumar    15000
# Name: Total_Sales, dtype: int64

# %%
df.to_excel("final_data.xlsx", index=False)
print("File created successfully")
# Out:
# File created successfully

# %%
print("Total Sales:", df["Total_Sales"].sum())
print(df.groupby("Category")["Total_Sales"].sum())
print(df.groupby("Region")["Total_Sales"].sum())
print(df.groupby("Customer")["Total_Sales"].sum().sort_values(ascending=False))
# Out:
# Total Sales: 62000
# Category
# Clothing       13000
# Electronics    49000
# Name: Total_Sales, dtype: int64
# Region
# East      9000
# North     4000
# South    25000
# West     24000
# Name: Total_Sales, dtype: int64
# Customer
# Ravi     28000
# Siva     19000
# Kumar    15000
# Name: Total_Sales, dtype: int64

# %%
print(df.isnull().sum())
df["Total_Sales"] = df["Price"] * df["Quantity"]
print(df)
# Out:
# Order_ID    0
# Customer    0
# Category    0
# Price       0
# Quantity    0
# Region      0
# dtype: int64
#    Order_ID Customer     Category  Price  Quantity Region  Total_Sales
# 0         1     Siva  Electronics  10000         1  South        10000
# 1         2     Ravi     Clothing   2000         2  North         4000
# 2         3    Kumar  Electronics  15000         1  South        15000
# 3         4     Siva     Clothing   3000         3   East         9000
# 4         5     Ravi  Electronics  12000         2   West        24000

# %%
import pandas as pd

data = {
    "Order_ID": [1,2,3,4,5],
    "Customer": ["Siva","Ravi","Kumar","Siva","Ravi"],
    "Category": ["Electronics","Clothing","Electronics","Clothing","Electronics"],
    "Price": [10000,2000,15000,3000,12000],
    "Quantity": [1,2,1,3,2],
    "Region": ["South","North","South","East","West"]
}

df = pd.DataFrame(data)

print(df)
# Out:
#    Order_ID Customer     Category  Price  Quantity Region
# 0         1     Siva  Electronics  10000         1  South
# 1         2     Ravi     Clothing   2000         2  North
# 2         3    Kumar  Electronics  15000         1  South
# 3         4     Siva     Clothing   3000         3   East
# 4         5     Ravi  Electronics  12000         2   West
